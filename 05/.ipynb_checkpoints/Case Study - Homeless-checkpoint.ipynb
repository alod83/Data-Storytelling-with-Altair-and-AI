# %% [markdown]
# # Case Study - Homeless

# %%
import pandas as pd
df = pd.read_csv('source/homeless_by_regions_2021.csv', sep=';')
df
# Out:
#     ITTER107                      Territorio    TIPO_DATO_CENS_POP  \
# 0       ITC1                        Piemonte  PR_SEC_HOMELESS_PERS
# 1       ITC1                        Piemonte  PR_SEC_HOMELESS_PERS
# 2       ITC1                        Piemonte  PR_SEC_HOMELESS_PERS
# 3       ITC2  Valle d'Aosta / Vallée d'Aoste  PR_SEC_HOMELESS_PERS
# 4       ITC2  Valle d'Aosta / Vallée d'Aoste  PR_SEC_HOMELESS_PERS
# ..       ...                             ...                   ...
# 972     ITE1                         Toscana  PR_SEC_HOMELESS_PERS
# 973     ITD4           Friuli-Venezia Giulia  PR_SEC_HOMELESS_PERS
# 974     ITC2  Valle d'Aosta / Vallée d'Aoste  PR_SEC_HOMELESS_PERS
# 975     ITD5                  Emilia-Romagna  PR_SEC_HOMELESS_PERS
# 976     ITE2                          Umbria  PR_SEC_HOMELESS_PERS
#
#                                     Tipo dato SEXISTAT1    Sesso    ETA1  \
# 0    persone senza tetto e senza fissa dimora         M   maschi   TOTAL
# 1    persone senza tetto e senza fissa dimora         F  femmine   TOTAL
# 2    persone senza tetto e senza fissa dimora         T   totale   TOTAL
# 3    persone senza tetto e senza fissa dimora         M   maschi   TOTAL
# 4    persone senza tetto e senza fissa dimora         F  femmine   TOTAL
# ..                                        ...       ...      ...     ...
# 972  persone senza tetto e senza fissa dimora         F  femmine  Y_GE55
# 973  persone senza tetto e senza fissa dimora         T   totale  Y_GE55
# 974  persone senza tetto e senza fissa dimora         F  femmine  Y35-54
# 975  persone senza tetto e senza fissa dimora         M   maschi  Y35-54
# 976  persone senza tetto e senza fissa dimora         M   maschi  Y_GE55
#
#      Classe di età CITTADINANZA         Cittadinanza  TIME  Seleziona periodo  \
# 0           totale          ITL           italiano-a  2021               2021
# 1           totale          ITL           italiano-a  2021               2021
# 2           totale          ITL           italiano-a  2021               2021
# 3           totale          ITL           italiano-a  2021               2021
# 4           totale          ITL           italiano-a  2021               2021
# ..             ...          ...                  ...   ...                ...
# 972  55 anni e più       FRGAPO  straniero-a/apolide  2021               2021
# 973  55 anni e più       FRGAPO  straniero-a/apolide  2021               2021
# 974     35-54 anni       FRGAPO  straniero-a/apolide  2021               2021
# 975     35-54 anni       FRGAPO  straniero-a/apolide  2021               2021
# 976  55 anni e più        TOTAL               totale  2021               2021
#
#      Value  Flag Codes  Flags
# 0     4218         NaN    NaN
# 1     1496         NaN    NaN
# 2     5714         NaN    NaN
# 3       41         NaN    NaN
# 4       17         NaN    NaN
# ..     ...         ...    ...
# 972     79         NaN    NaN
# 973     45         NaN    NaN
# 974      1         NaN    NaN
# 975    466         NaN    NaN
# 976    107         NaN    NaN
#
# [977 rows x 15 columns]

# %% [markdown]
# Select only some fields

# %%
df = df[['ITTER107','Territorio','SEXISTAT1', 'ETA1', 'CITTADINANZA', 'Value']]
df['Territorio'] = df['Territorio'].str.replace('Trentino Alto Adige / Südtirol', 'Trentino-Alto Adige/Südtirol')

# %% [markdown]
# Focus on total age, total sex and total citizenship

# %%
df_tot = df[(df['ETA1'] == 'TOTAL') & (df['SEXISTAT1'] == 'T') &  (df['CITTADINANZA'] == 'TOTAL')]

# %% [markdown]
# ## Draw a preliminary map

# %%
import altair as alt

# Load the TopoJSON file by URL
url = "https://raw.githubusercontent.com/openpolis/geojson-italy/master/topojson/limits_IT_regions.topo.json"


source = alt.topo_feature(url, "regions")

alt.Chart(source).mark_geoshape().encode(
    tooltip='properties.reg_name:N',
    color=alt.Color('Value:Q')
).project('mercator').properties(
    width=500,
    height=500
).transform_lookup(
    lookup='properties.reg_name',
    from_=alt.LookupData(df_tot, 'Territorio', ['Territorio', 'Value'])
).properties(title='Homeless in Italy in 2021')
# Out:
# alt.Chart(...)

# %% [markdown]
# Normalize by population

# %%
df2 = pd.read_csv('source/population_by_regions_2021.csv')
df2
# Out:
#      ITTER107                      Territorio TIPO_DATO_CENS_POP  \
# 0        ITD4           Friuli-Venezia Giulia          RESPOP_AV
# 1        ITE1                         Toscana          RESPOP_AV
# 2        ITF6                        Calabria          RESPOP_AV
# 3        ITD2       Provincia Autonoma Trento          RESPOP_AV
# 4        ITD3                          Veneto          RESPOP_AV
# ...       ...                             ...                ...
# 1447     ITDA  Trentino Alto Adige / Südtirol          RESPOP_AV
# 1448     ITDA  Trentino Alto Adige / Südtirol          RESPOP_AV
# 1449     ITDA  Trentino Alto Adige / Südtirol          RESPOP_AV
# 1450     ITDA  Trentino Alto Adige / Südtirol          RESPOP_AV
# 1451     ITDA  Trentino Alto Adige / Südtirol          RESPOP_AV
#
#                   Tipo dato SEXISTAT1    Sesso    ETA1  Classe di età  TIME  \
# 0     popolazione residente         M   maschi   Y_UN4  fino a 4 anni  2021
# 1     popolazione residente         M   maschi   Y_UN4  fino a 4 anni  2021
# 2     popolazione residente         M   maschi   Y_UN4  fino a 4 anni  2021
# 3     popolazione residente         T   totale    Y5-9       5-9 anni  2021
# 4     popolazione residente         M   maschi    Y5-9       5-9 anni  2021
# ...                     ...       ...      ...     ...            ...   ...
# 1447  popolazione residente         F  femmine  Y30-34     30-34 anni  2021
# 1448  popolazione residente         T   totale  Y20-24     20-24 anni  2021
# 1449  popolazione residente         M   maschi  Y70-74     70-74 anni  2021
# 1450  popolazione residente         M   maschi  Y80-84     80-84 anni  2021
# 1451  popolazione residente         F  femmine  Y50-54     50-54 anni  2021
#
#       Seleziona periodo   Value  Flag Codes  Flags
# 0                  2021   19794         NaN    NaN
# 1                  2021   61789         NaN    NaN
# 2                  2021   36842         NaN    NaN
# 3                  2021   25101         NaN    NaN
# 4                  2021  105344         NaN    NaN
# ...                 ...     ...         ...    ...
# 1447               2021   29518         NaN    NaN
# 1448               2021   59099         NaN    NaN
# 1449               2021   25405         NaN    NaN
# 1450               2021   15882         NaN    NaN
# 1451               2021   42905         NaN    NaN
#
# [1452 rows x 13 columns]

# %%
df2_tot = df2[(df2['ETA1'] == 'TOTAL') & (df2['Sesso'] == 'totale')]
df2_tot['Territorio'] = df2_tot['Territorio'].str.replace('Trentino Alto Adige / Südtirol', 'Trentino-Alto Adige/Südtirol')
# Out:
# /var/folders/yc/q002jxmj3lb5jz2p9nrxyt840000gn/T/ipykernel_717/3899617481.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_tot['Territorio'] = df2_tot['Territorio'].str.replace('Trentino Alto Adige / Südtirol', 'Trentino-Alto Adige/Südtirol')

# %%
len(df_tot), len(df2_tot)
# Out:
# (22, 22)

# %% [markdown]
# Join the two datasets

# %%
df_tot = df_tot[['Value', 'ITTER107']]
df2_tot = df2_tot[['Value', 'ITTER107','Territorio']]

# %%
df3 = df2_tot.set_index('ITTER107').join(df_tot.set_index('ITTER107'),lsuffix='_pop', rsuffix='_hom').reset_index()

# %% [markdown]
# Calculate ratio: number of homeless people over 1000 inhabitants

# %%
df3['Ratio'] = df3['Value_hom']/df3['Value_pop']*1000

# %%
# Load the TopoJSON file by URL
url = "https://raw.githubusercontent.com/openpolis/geojson-italy/master/topojson/limits_IT_regions.topo.json"


source = alt.topo_feature(url, "regions")

alt.Chart(source).mark_geoshape().encode(
    tooltip='properties.reg_name:N',
    color=alt.Color('Ratio:Q')
).project('mercator').properties(
    width=500,
    height=500
).transform_lookup(
    lookup='properties.reg_name',
    from_=alt.LookupData(df3, 'Territorio', ['Territorio', 'Ratio'])
).properties(title='Homeless in Italy in 2021')
# Out:
# alt.Chart(...)

# %% [markdown]
# Drop Trentino Provinces

# %%
df3.drop(labels=[11,1], axis=0,inplace=True)

# %%
alt.Chart(df3).mark_bar().encode(
    y = alt.Y('Territorio', sort='-x'),
    x = alt.X('Ratio')
   
).properties(width=500)
# Out:
# /Users/angelica/Library/Python/3.8/lib/python/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
alt.Chart(df3).mark_bar().encode(
    y = alt.Y('Territorio', sort='-x'),
    x = alt.X('Value_hom'),
   
).properties(width=500)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df3).mark_bar().encode(
    y = alt.Y('Territorio', sort='-x', axis=alt.Axis(title='')),
    x = alt.X('Ratio', axis=alt.Axis(tickCount=4,title='')),
    color=alt.condition(alt.datum.Ratio > 2, alt.value('darkred'), alt.value('lightgray'))
   
).properties(width=500,title='Number of homeless people in a population of 1,000')
# Out:
# alt.Chart(...)
